# %%
import json
import requests

eat = input("Enter a recipe that you'd like to eat: ")
url = 'https://api.spoonacular.com/recipes/search'
params = {'query' : eat, 'apiKey' : 'af0adcdfc2f74bd5943e1d54dd154b98', 'instructionsRequired' : True }
response = requests.get(url, params = params)
print(response.url)
recipe = response.json()
recipe
# Out:
# Enter a recipe that you'd like to eat: muffins
# https://api.spoonacular.com/recipes/search?query=muffins&apiKey=af0adcdfc2f74bd5943e1d54dd154b98&instructionsRequired=True
# {'results': [{'id': 563303,
#    'title': 'Peach Muffin (Paleo, Gluten Free, Grain Free)',
#    'readyInMinutes': 35,
#    'servings': 9,
#    'image': 'Fresh-Peach-Paleo-Muffins-563303.jpg',
#    'imageUrls': ['Fresh-Peach-Paleo-Muffins-563303.jpg']},
#   {'id': 482104,
#    'title': 'Lemon Coconut Poppy Seed Muffins',
#    'readyInMinutes': 28,
#    'servings': 12,
#    'image': 'Lemon-Coconut-Poppy-Seed-Muffins-482104.jpg',
#    'imageUrls': ['Lemon-Coconut-Poppy-Seed-Muffins-482104.jpg']},
#   {'id': 489500,
#    'title': 'Chocolate Zucchini Muffins',
#    'readyInMinutes': 30,
#    'servings': 12,
#    'image': 'Chocolate-Zucchini-Muffins-489500.jpg',
#    'imageUrls': ['Chocolate-Zucchini-Muffins-489500.jpg']},
#   {'id': 246700,
#    'title': 'Banana Nut Muffins',
#    'readyInMinutes': 40,
# ...

# %%
ident = input("Enter a recipe number ")
url = 'https://api.spoonacular.com/recipes/%s/information' % ident
params = {'apiKey' : 'af0adcdfc2f74bd5943e1d54dd154b98' }
response = requests.get(url, params = params)
print(response.url)
recipe = response.json()
recipe
# Out:
# Enter a recipe number 563303
# https://api.spoonacular.com/recipes/563303/information?apiKey=af0adcdfc2f74bd5943e1d54dd154b98
# {'vegetarian': True,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': False,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': True,
#  'sustainable': False,
#  'weightWatcherSmartPoints': 6,
#  'gaps': 'GAPS_FULL',
#  'lowFodmap': False,
#  'ketogenic': False,
#  'whole30': False,
#  'preparationMinutes': 10,
#  'cookingMinutes': 25,
#  'sourceUrl': 'https://cookeatpaleo.com/peach-paleo-muffins/',
#  'spoonacularSourceUrl': 'https://spoonacular.com/peach-muffin-paleo-gluten-free-grain-free-563303',
#  'aggregateLikes': 3780,
#  'spoonacularScore': 18.0,
#  'healthScore': 1.0,
#  'creditsText': 'Cook Eat Paleo',
#  'sourceName': 'Cook Eat Paleo',
#  'pricePerServing': 73.34,
#  'extendedIngredients': [{'id': 9236,
#    'aisle': 'Produce',
#    'image': 'peach.png',
#    'consitency': 'solid',
#    'name': 'peaches',
# ...

# %%
count = 0
for i in L
print(count, i)
count+= 1
